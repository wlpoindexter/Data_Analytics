# %% [markdown]
# Lab 2 of Exercise 2.B, working
# with datetime functions.

# %%
import datetime

# %% [markdown]
# # Today

# %%
today = datetime.datetime.now()

# %%
print(today.strftime("Today is %A, %B %d, %Y"))
# Out:
# Today is Sunday, May 24, 2026

# %% [markdown]
# # My birthday

# %%
birthday = datetime.date(1997, 11, 10)

# %%
print(birthday.strftime("My birthday is %m/%d/%Y"))
# Out:
# My birthday is 11/10/1997

# %% [markdown]
# # Next 90 Days

# %%
ninety_d = today + datetime.timedelta(days=90)

# %%
print(ninety_d.strftime("90 days from today is %B %d, %Y"))
# Out:
# 90 days from today is August 22, 2026

# %% [markdown]
# # Time for Dinner

# %%
dinner_time = datetime.time(7, 30)

# %%
print(dinner_time.strftime("Let's meet for dinner at %I:%M %p"))
# Out:
# Let's meet for dinner at 07:30 AM
